# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from pathlib import Path
from pprint import pprint

# %%
trackpath = Path.cwd() / 'Resources' / 'data.csv'
df = pd.read_csv(trackpath, encoding='ANSI')
# Taking just the first 10 rows to speed things up
df = df.head(10)

# %%
client_id = 'ee2b858721d248bb92681bca5fd6af5e'
client_secret = '59a96b7e0a7b48fe94e027dd77aa518a'

client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
def getTrackIDs(user, playlist_id):
    ids = []
    playlist = sp.user_playlist(user, playlist_id)
    for item in playlist['tracks']['items']:
        track = item['track']
        ids.append(track['id'])
    return ids

def getTrackInfo(trackID):
    trackData = sp.track(trackID)
    trackFeature = sp.audio_features(trackID)
    # Audio Analysis doesn't have a lot of very useful data, but there is a LOT of data. 
#     trackAudioAnalysis = sp.audio_analysis(trackID)

    # Pull out the track info
    name = trackData['name']
    album = trackData['album']['name']
    artist = trackData['album']['artists'][0]['name']
    release_date = trackData['album']['release_date']
    length = trackData['duration_ms']
    popularity = trackData['popularity']

    # Pull out the track audio features    
    acousticness = trackFeature[0]['acousticness']
    danceability = trackFeature[0]['danceability']
    energy = trackFeature[0]['energy']
    instrumentalness = trackFeature[0]['instrumentalness']
    liveness = trackFeature[0]['liveness']
    loudness = trackFeature[0]['loudness']
    speechiness = trackFeature[0]['speechiness']
    tempo = trackFeature[0]['tempo']
    timeSignature = trackFeature[0]['time_signature']

    trackInfo = [trackID, name, album, artist, release_date, length, popularity, danceability, acousticness, danceability, energy, instrumentalness, liveness, loudness, speechiness, tempo, timeSignature]
    
    return trackInfo

# %%
tempID = []
for index, row in df.iterrows():
    print(f'Working on row {index}')
    try:
        temp = row['URL']
        temp = temp[31:]
        tempID.append(temp)
    except:
        print(f'Error on row {index}')
df['TrackID'] = tempID
# Out:
# Working on row 0
# Working on row 1
# Working on row 2
# Working on row 3
# Working on row 4
# Working on row 5
# Working on row 6
# Working on row 7
# Working on row 8
# Working on row 9

# %%
tempTrack = []
for i in range(len(tempID)):
    track = getTrackInfo(tempID[i])
    tempTrack.append(track)

# %%
colName = ['trackID', 'name', 'album', 'artist', 'release_date', 'length', 'popularity', 'danceability', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'timeSignature']
data_df = pd.DataFrame(data=tempTrack, columns=colName)

# %%
data_df
# Out:
#                   trackID                                         name  \
# 0  3AEZUABDXNtecAOSC1qTfo                   Reggaetón Lento (Bailemos)
# 1  6mICuAdrwEjh6Y6lroV2Kg                      Chantaje (feat. Maluma)
# 2  3QwBODjSEzelZyVjxPOHdq                    Otra vez (feat. J Balvin)
# 3  7DM4BPaS7uofFul3ywMe46                  Vente Pa' Ca (feat. Maluma)
# 4  6rQSrBHf7HlZjtcMZ4S4bO                                       Safari
# 5  0sXvAOmXgjR2QUqLK1MltU                                 La Bicicleta
# 6  6stYbAJgTszHAHZMPxWWCY  Ay Mi Dios (feat. Pitbull, Yandel & Chacal)
# 7  5mey7CLLuFToM2P68Qu1gF                           Andas En Mi Cabeza
# 8  5J1c3M4EldCfNxXwrwt8mT                                  Traicionera
# 9  58IL315gMSTD37DOZPJ2hf                                  Shaky Shaky
#
#                                          album           artist release_date  \
# 0                                 Primera Cita             CNCO   2016-08-26
# 1                                    El Dorado          Shakira   2017-05-26
# 2                                     Motivan2    Zion & Lennox   2016-09-30
# 3                  Vente Pa' Ca (feat. Maluma)     Ricky Martin   2016-09-22
# 4                                      Energía         J Balvin   2016-06-24
# 5                                    El Dorado          Shakira   2017-05-26
# 6  Ay Mi Dios (feat. Pitbull, Yandel & Chacal)         IAmChino   2016-02-22
# 7                           Andas En Mi Cabeza    Chino & Nacho   2016-02-19
# 8                                  Traicionera  Sebastian Yatra   2016-06-24
# 9                                  Shaky Shaky     Daddy Yankee   2016-04-08
#
#    length  popularity  danceability  acousticness  danceability  energy  \
# 0  222560          73         0.761       0.40000         0.761   0.838
# 1  195840          75         0.852       0.18700         0.852   0.773
# 2  209453          73         0.832       0.05590         0.832   0.772
# 3  259195          72         0.663       0.00431         0.663   0.920
# 4  205600           1         0.508       0.55100         0.508   0.687
# 5  227706          60         0.736       0.19800         0.736   0.964
# 6  252003           0         0.761       0.16700         0.761   0.829
# 7  247493           0         0.680       0.02440         0.680   0.954
# 8  228466           1         0.776       0.14200         0.776   0.669
# 9  234320           0         0.899       0.07600         0.899   0.626
#
#    instrumentalness  liveness  loudness  speechiness    tempo  timeSignature
# 0          0.000000    0.1760    -3.073       0.0502   93.974              4
# 1          0.000030    0.1590    -2.921       0.0776  102.034              4
# 2          0.000486    0.4400    -5.429       0.1000   96.016              4
# 3          0.000017    0.1010    -4.070       0.2260   99.935              4
# 4          0.000003    0.1260    -4.361       0.3260  180.044              4
# 5          0.000002    0.3360    -2.147       0.1290  179.935              4
# 6          0.000000    0.1890    -3.203       0.0681   92.033              4
# 7          0.000000    0.1120    -1.823       0.1190  104.029              4
# 8          0.000000    0.2190    -4.933       0.0638   91.012              4
# 9          0.000000    0.0631    -4.228       0.2920   88.007              4
