# %%
# Import 
from pathlib import Path
import pandas as pd

# %%
# Load files
readpath = Path.cwd() / 'Resources' / 'data.csv'
readpath
# Out:
# WindowsPath('C:/Users/Cam Foster/Documents/Education/Georgia Tech/Homework/Project_One/Project-One/Resources/data.csv')

# %%
spotipyDF = pd.read_csv(readpath, encoding = "ANSI")

# %%
spotipyDF.head()
# Out:
#    Position                   TrackName        Artist   Streams  \
# 0         1                    Chantaje       Shakira  253019.0
# 1         2                Vente Pa' Ca  Ricky Martin  223988.0
# 2         3  Reggaetón Lento (Bailemos)          CNCO  210943.0
# 3         4                      Safari      J Balvin  173865.0
# 4         5                 Shaky Shaky  Daddy Yankee  153956.0
#
#                                                  URL      Date Region
# 0  https://open.spotify.com/track/6mICuAdrwEjh6Y6...  1/1/2017     ar
# 1  https://open.spotify.com/track/7DM4BPaS7uofFul...  1/1/2017     ar
# 2  https://open.spotify.com/track/3AEZUABDXNtecAO...  1/1/2017     ar
# 3  https://open.spotify.com/track/6rQSrBHf7HlZjtc...  1/1/2017     ar
# 4  https://open.spotify.com/track/58IL315gMSTD37D...  1/1/2017     ar

# %%
spotipyDF = spotipyDF.dropna(how='any')

# %%
# Clean any misc. rows that contain questionable artist names

spotipyDF = spotipyDF[spotipyDF.Artist != "Z"]
spotipyDF = spotipyDF[spotipyDF.Artist != "13 Block"]
spotipyDF = spotipyDF[spotipyDF.Artist != "10cm"]
spotipyDF = spotipyDF[spotipyDF.Artist != "070 Shake"]
spotipyDF = spotipyDF[spotipyDF.Artist != "6150"]
spotipyDF = spotipyDF[~spotipyDF['Artist'].str.contains('\?')]
spotipyDF = spotipyDF[spotipyDF.Artist != "?"]
spotipyDF = spotipyDF[spotipyDF.Artist != "100%"]
spotipyDF
# Out:
#          Position                               TrackName        Artist  \
# 0               1                                Chantaje       Shakira
# 1               2                            Vente Pa' Ca  Ricky Martin
# 2               3              Reggaetón Lento (Bailemos)          CNCO
# 3               4                                  Safari      J Balvin
# 4               5                             Shaky Shaky  Daddy Yankee
# ...           ...                                     ...           ...
# 1048569       196                                Portland         Drake
# 1048570       197                               All On Me  Devin Dawson
# 1048571       198  From The D To The A (feat. Lil Yachty)  Tee Grizzley
# 1048572       199                            Now Or Never        Halsey
# 1048573       200                So Good (& Metro Boomin)      Big Sean
#
#           Streams                                                URL  \
# 0        253019.0  https://open.spotify.com/track/6mICuAdrwEjh6Y6...
# 1        223988.0  https://open.spotify.com/track/7DM4BPaS7uofFul...
# 2        210943.0  https://open.spotify.com/track/3AEZUABDXNtecAO...
# 3        173865.0  https://open.spotify.com/track/6rQSrBHf7HlZjtc...
# 4        153956.0  https://open.spotify.com/track/58IL315gMSTD37D...
# ...           ...                                                ...
# 1048569  184537.0  https://open.spotify.com/track/2bjwRfXMk4uRgOD...
# 1048570  184519.0  https://open.spotify.com/track/2mfahQ0EaaZWq4c...
# 1048571  184428.0  https://open.spotify.com/track/2NyrXRn4tancYPW...
# 1048572  184394.0  https://open.spotify.com/track/7i2DJ88J7jQ8K7z...
# 1048573  184149.0  https://open.spotify.com/track/0fWBFDRTIuk8ZgN...
#
#              Date Region
# 0        1/1/2017     ar
# 1        1/1/2017     ar
# 2        1/1/2017     ar
# 3        1/1/2017     ar
# 4        1/1/2017     ar
# ...           ...    ...
# 1048569  1/9/2018     us
# 1048570  1/9/2018     us
# 1048571  1/9/2018     us
# 1048572  1/9/2018     us
# 1048573  1/9/2018     us
#
# [1044553 rows x 7 columns]

# %%
# Clean any misc. rows that contain questionable track names

spotipyDF = spotipyDF[spotipyDF.TrackName != ""]
spotipyDF = spotipyDF[~spotipyDF['TrackName'].str.contains('\?')]
spotipyDF
# Out:
#          Position                               TrackName        Artist  \
# 0               1                                Chantaje       Shakira
# 1               2                            Vente Pa' Ca  Ricky Martin
# 2               3              Reggaetón Lento (Bailemos)          CNCO
# 3               4                                  Safari      J Balvin
# 4               5                             Shaky Shaky  Daddy Yankee
# ...           ...                                     ...           ...
# 1048569       196                                Portland         Drake
# 1048570       197                               All On Me  Devin Dawson
# 1048571       198  From The D To The A (feat. Lil Yachty)  Tee Grizzley
# 1048572       199                            Now Or Never        Halsey
# 1048573       200                So Good (& Metro Boomin)      Big Sean
#
#           Streams                                                URL  \
# 0        253019.0  https://open.spotify.com/track/6mICuAdrwEjh6Y6...
# 1        223988.0  https://open.spotify.com/track/7DM4BPaS7uofFul...
# 2        210943.0  https://open.spotify.com/track/3AEZUABDXNtecAO...
# 3        173865.0  https://open.spotify.com/track/6rQSrBHf7HlZjtc...
# 4        153956.0  https://open.spotify.com/track/58IL315gMSTD37D...
# ...           ...                                                ...
# 1048569  184537.0  https://open.spotify.com/track/2bjwRfXMk4uRgOD...
# 1048570  184519.0  https://open.spotify.com/track/2mfahQ0EaaZWq4c...
# 1048571  184428.0  https://open.spotify.com/track/2NyrXRn4tancYPW...
# 1048572  184394.0  https://open.spotify.com/track/7i2DJ88J7jQ8K7z...
# 1048573  184149.0  https://open.spotify.com/track/0fWBFDRTIuk8ZgN...
#
#              Date Region
# 0        1/1/2017     ar
# 1        1/1/2017     ar
# 2        1/1/2017     ar
# 3        1/1/2017     ar
# 4        1/1/2017     ar
# ...           ...    ...
# 1048569  1/9/2018     us
# 1048570  1/9/2018     us
# 1048571  1/9/2018     us
# 1048572  1/9/2018     us
# 1048573  1/9/2018     us
#
# [1015314 rows x 7 columns]

# %%
# Filter data to only use US data in 2017

spotipyDF = spotipyDF[spotipyDF["Region"] == "us"]
spotipyDF
# Out:
#          Position                               TrackName            Artist  \
# 2722            1     Bad and Boujee (feat. Lil Uzi Vert)             Migos
# 2723            2                               Fake Love             Drake
# 2724            3                                 Starboy        The Weeknd
# 2725            4                                  Closer  The Chainsmokers
# 2726            5                           Black Beatles      Rae Sremmurd
# ...           ...                                     ...               ...
# 1048569       196                                Portland             Drake
# 1048570       197                               All On Me      Devin Dawson
# 1048571       198  From The D To The A (feat. Lil Yachty)      Tee Grizzley
# 1048572       199                            Now Or Never            Halsey
# 1048573       200                So Good (& Metro Boomin)          Big Sean
#
#            Streams                                                URL  \
# 2722     1371493.0  https://open.spotify.com/track/4Km5HrUvYTaSUfi...
# 2723     1180074.0  https://open.spotify.com/track/343YBumqHu19cGo...
# 2724     1064351.0  https://open.spotify.com/track/5aAx2yezTd8zXrk...
# 2725     1010492.0  https://open.spotify.com/track/7BKLCZ1jbUBVqRi...
# 2726      874289.0  https://open.spotify.com/track/6fujklziTHa8uoM...
# ...            ...                                                ...
# 1048569   184537.0  https://open.spotify.com/track/2bjwRfXMk4uRgOD...
# 1048570   184519.0  https://open.spotify.com/track/2mfahQ0EaaZWq4c...
# 1048571   184428.0  https://open.spotify.com/track/2NyrXRn4tancYPW...
# 1048572   184394.0  https://open.spotify.com/track/7i2DJ88J7jQ8K7z...
# 1048573   184149.0  https://open.spotify.com/track/0fWBFDRTIuk8ZgN...
#
#              Date Region
# 2722     1/1/2017     us
# 2723     1/1/2017     us
# 2724     1/1/2017     us
# 2725     1/1/2017     us
# 2726     1/1/2017     us
# ...           ...    ...
# 1048569  1/9/2018     us
# 1048570  1/9/2018     us
# 1048571  1/9/2018     us
# 1048572  1/9/2018     us
# 1048573  1/9/2018     us
#
# [73934 rows x 7 columns]

# %%
spotipyDF['Year'] = spotipyDF['Date'].str.extract('.*(\d{2})', expand = False)
spotipyDF.head()
# Out:
# <ipython-input-10-75f9bc9f1f09>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spotipyDF['Year'] = spotipyDF['Date'].str.extract('.*(\d{2})', expand = False)
#       Position                            TrackName            Artist  \
# 2722         1  Bad and Boujee (feat. Lil Uzi Vert)             Migos
# 2723         2                            Fake Love             Drake
# 2724         3                              Starboy        The Weeknd
# 2725         4                               Closer  The Chainsmokers
# 2726         5                        Black Beatles      Rae Sremmurd
#
#         Streams                                                URL      Date  \
# 2722  1371493.0  https://open.spotify.com/track/4Km5HrUvYTaSUfi...  1/1/2017
# 2723  1180074.0  https://open.spotify.com/track/343YBumqHu19cGo...  1/1/2017
# 2724  1064351.0  https://open.spotify.com/track/5aAx2yezTd8zXrk...  1/1/2017
# 2725  1010492.0  https://open.spotify.com/track/7BKLCZ1jbUBVqRi...  1/1/2017
# 2726   874289.0  https://open.spotify.com/track/6fujklziTHa8uoM...  1/1/2017
#
#      Region Year
# 2722     us   17
# 2723     us   17
# 2724     us   17
# 2725     us   17
# 2726     us   17

# %%
# Create buckets of streaming values

bins = [0, 50000, 250000, 500000 , 750000, 1000000, 1500000, 2000000, 2500000, 3000000]
binNames = ["<50,000","50,001 - 250,000", "250,001 - 500,000", "500,001 - 750,000", "750,001 - 1,000,000", "1,000,001 - 1,500,000", "1,500,001 - 2,000,000", "2,000,001 - 2,500,000", "2,500,001 - 3,000,000", ">3,000,001"]
spotipyDF["bins"] = pd.cut(spotipyDF["Streams"], bins, labels = binNames)
grouping = spotipyDF.groupby("bins")
spotipyDF
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-69aadda72d46> in <module>
#       3 bins = [0, 50000, 250000, 500000 , 750000, 1000000, 1500000, 2000000, 2500000, 3000000]
#       4 binNames = ["<50,000","50,001 - 250,000", "250,001 - 500,000", "500,001 - 750,000", "750,001 - 1,000,000", "1,000,001 - 1,500,000", "1,500,001 - 2,000,000", "2,000,001 - 2,500,000", "2,500,001 - 3,000,000", ">3,000,001"]
# ----> 5 spotipyDF["bins"] = pd.cut(spotipyDF["Streams"], bins, labels = binNames)
#       6 grouping = spotipyDF.groupby("bins")
#       7 spotipyDF
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates)
#     255             raise ValueError("bins must increase monotonically.")
#     256
# --> 257     fac, bins = _bins_to_cuts(
#     258         x,
#     259         bins,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\tile.py in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates)
#     408         else:
#     409             if len(labels) != len(bins) - 1:
# --> 410                 raise ValueError(
#     411                     "Bin labels must be one fewer than the number of bin edges"
#     412                 )
#
# ValueError: Bin labels must be one fewer than the number of bin edges

# %%
spotipyDF = spotipyDF[spotipyDF.Year != '18']

# %%
printpath = Path.cwd() / 'Resources' / 'cleanData.csv'
spotipyDF.to_csv(printpath)
